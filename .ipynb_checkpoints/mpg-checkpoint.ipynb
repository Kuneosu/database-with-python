# %%
import pandas as pd
import numpy as np
mpg = pd.read_csv('mpg.csv')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
mpg.head(2)
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact

# %%
mpg.tail()
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize

# %%
mpg.shape
# Out:
# (234, 11)

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
# 0 manufacturer : 제조 회사
# 1 model : 자동차 모델명
# 2 displ : 배기량
# 3 year : 생산연도
# 4 cyl : 실린더 개수
# 5 trans : 변속기 종류
# 6 drv : 구동 방식
# 7 cty : 도시 연비
# 8 hwy : 고속도로 연비
# 9 f1 : 연료 종류
# 10 category : 자동차 종류

# %%
mpg.describe(include ='all')
# Out:
#        manufacturer        model       displ         year         cyl  \
# count           234          234  234.000000   234.000000  234.000000
# unique           15           38         NaN          NaN         NaN
# top           dodge  caravan 2wd         NaN          NaN         NaN
# freq             37           11         NaN          NaN         NaN
# mean            NaN          NaN    3.471795  2003.500000    5.888889
# std             NaN          NaN    1.291959     4.509646    1.611534
# min             NaN          NaN    1.600000  1999.000000    4.000000
# 25%             NaN          NaN    2.400000  1999.000000    4.000000
# 50%             NaN          NaN    3.300000  2003.500000    6.000000
# 75%             NaN          NaN    4.600000  2008.000000    8.000000
# max             NaN          NaN    7.000000  2008.000000    8.000000
#
#            trans  drv         cty         hwy   fl category
# count        234  234  234.000000  234.000000  234      234
# ...

# %%
# unique : 고유값 빈도 : 중복을 제거한 볌주의 개수
# top : 최빈값 : 개수가 가장 많은 값
# freq : 최빈값 빈도 : 개수가 가장 많은 값의 개수
# NaN : 결측치 : 누락된 값

# %%
mpg_copy = mpg.copy()
mpg_copy.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
mpg_copy = mpg_copy.rename(columns = {'cty':'city','hwy':'highway'})
mpg_copy
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#     category
# 0    compact
# 1    compact
# ...

# %%
mpg['total'] = (mpg['cty']+mpg['hwy'])/2

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total
# 0   23.5
# 1   25.0
# 2   25.5
# 3   25.5
# 4   21.0

# %%
sum(mpg['total']) / len(mpg)
# Out:
# 20.14957264957265

# %%
mpg['total'].mean()
# Out:
# 20.14957264957265

# %%
mpg['total'].describe()
# Out:
# count    234.000000
# mean      20.149573
# std        5.050290
# min       10.500000
# 25%       15.500000
# 50%       20.500000
# 75%       23.500000
# max       39.500000
# Name: total, dtype: float64

# %%
mpg['total'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import numpy as np
mpg['test'] = np.where(mpg['total']>=20,'pass','fail')

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  test
# 0   23.5  pass
# 1   25.0  pass
# 2   25.5  pass
# 3   25.5  pass
# 4   21.0  pass

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category  total  test
# 0    compact   23.5  pass
# 1    compact   25.0  pass
# ...

# %%
mpg.head(10)
# Out:
#   manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0         audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1         audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2         audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3         audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 4         audi          a4    2.8  1999    6    auto(l5)   f   16   26  p
# 5         audi          a4    2.8  1999    6  manual(m5)   f   18   26  p
# 6         audi          a4    3.1  2008    6    auto(av)   f   18   27  p
# 7         audi  a4 quattro    1.8  1999    4  manual(m5)   4   18   26  p
# 8         audi  a4 quattro    1.8  1999    4    auto(l5)   4   16   25  p
# 9         audi  a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
#
#   category  total  test
# 0  compact   23.5  pass
# 1  compact   25.0  pass
# 2  compact   25.5  pass
# 3  compact   25.5  pass
# 4  compact   21.0  pass
# ...

# %%
mpg.tail(10)
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 224   volkswagen  new beetle    2.0  1999    4    auto(l4)   f   19   26  r
# 225   volkswagen  new beetle    2.5  2008    5  manual(m5)   f   20   28  r
# 226   volkswagen  new beetle    2.5  2008    5    auto(s6)   f   20   29  r
# 227   volkswagen      passat    1.8  1999    4  manual(m5)   f   21   29  p
# 228   volkswagen      passat    1.8  1999    4    auto(l5)   f   18   29  p
# 229   volkswagen      passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen      passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen      passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen      passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen      passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        category  total  test
# 224  subcompact   22.5  pass
# 225  subcompact   24.0  pass
# 226  subcompact   24.5  pass
# ...

# %%
mpg.tail(20)
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 214   volkswagen       jetta    2.0  1999    4    auto(l4)   f   19   26  r
# 215   volkswagen       jetta    2.0  2008    4    auto(s6)   f   22   29  p
# 216   volkswagen       jetta    2.0  2008    4  manual(m6)   f   21   29  p
# 217   volkswagen       jetta    2.5  2008    5    auto(s6)   f   21   29  r
# 218   volkswagen       jetta    2.5  2008    5  manual(m5)   f   21   29  r
# 219   volkswagen       jetta    2.8  1999    6    auto(l4)   f   16   23  r
# 220   volkswagen       jetta    2.8  1999    6  manual(m5)   f   17   24  r
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
# 223   volkswagen  new beetle    2.0  1999    4  manual(m5)   f   21   29  r
# 224   volkswagen  new beetle    2.0  1999    4    auto(l4)   f   19   26  r
# ...

# %%
mpg['test'].value_counts()
# Out:
# pass    128
# fail    106
# Name: test, dtype: int64

# %%
count_test = mpg['test'].value_counts()
count_test.plot.bar()
# Out:
# <AxesSubplot:>

# %%
count_test.plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %%
mpg['grade'] = np.where(mpg['total'] >= 30,'A',
                       np.where(mpg['total'] >= 20,'B','C'))
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  test grade
# 0   23.5  pass     B
# 1   25.0  pass     B
# 2   25.5  pass     B
# 3   25.5  pass     B
# 4   21.0  pass     B

# %%
count_grade = mpg['grade'].value_counts()
count_grade
# Out:
# B    118
# C    106
# A     10
# Name: grade, dtype: int64

# %%
count_grade.plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %%
count_grade = count_grade.sort_index()
count_grade
# Out:
# A     10
# B    118
# C    106
# Name: grade, dtype: int64

# %%
count_grade.plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %%
# mpg['size'] = np.where((mpg['category'] == 'compact') |
#                      (mpg['category'] == 'subcompact') |
#                      (mpg['category'] == '2seater'),
#                      'small','large')
mpg['size'] = np.where(mpg['category'].isin(['compact',
                                            'subcompact',
                                            '2seater']),'small','large')
mpg['size'].value_counts()
# Out:
# large    147
# small     87
# Name: size, dtype: int64

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  test grade   size
# 0   23.5  pass     B  small
# 1   25.0  pass     B  small
# 2   25.5  pass     B  small
# 3   25.5  pass     B  small
# 4   21.0  pass     B  small

# %%
dis_d = mpg.query('displ <= 4')['hwy'].mean()

# %%
dis_u = mpg.query('displ >= 5')['hwy'].mean()

# %%
dis_d
# Out:
# 25.96319018404908

# %%
dis_u
# Out:
# 18.07894736842105

# %%
audi = mpg.query('manufacturer == "audi"')['cty'].mean()
audi
# Out:
# 17.61111111111111

# %%
toyota = mpg.query('manufacturer == "toyota"')['cty'].mean()
toyota
# Out:
# 18.529411764705884

# %%
hwy_avg = mpg.query('manufacturer in ["chevrolet","ford","honda"]')['hwy'].mean()
hwy_avg
# Out:
# 22.50943396226415
